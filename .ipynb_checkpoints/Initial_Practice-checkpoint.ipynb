# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %%
import matplotlib.pyplot as plt

# %%
Profit = (75000,80000,47000,55000,63000,47000,23000,99000,115000,123000,145000,213000)
Months = ("Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec")

# %%
plt.plot(Months,Profit)
plt.xlabel("Months")
plt.ylabel("Profit (US$)")
plt.title("Business Profitability")
plt.show()
